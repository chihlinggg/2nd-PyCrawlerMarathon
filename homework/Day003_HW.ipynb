# %% [markdown]
# # Python 下載XML檔案與解析
#
#
# * 了解 xml 檔案格式與內容
# * 能夠利用套件存取 xml 格式的檔案

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異
#
# * 根據範例檔案的結果：
#     1. 請問高雄市有多少地區有溫度資料？
#     2. 請取出每一個地區所記錄的第一個時間點跟溫度
#     3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %% [markdown]
# ### 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異

# %% [markdown]
#     (1) File I/O : 讀出來的內容為一個字串，無法對所需進行呼叫
#     (2) xmltodict : 讀出來的內容可依照所需進行呼叫

# %% [markdown]
# ### 根據範例檔案的結果：
#
# 1. 請問高雄市有多少地區有溫度資料？
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %%
# 下載檔案
import urllib.request
import zipfile

res = "http://opendata.cwb.gov.tw/govdownload?dataid=F-D0047-093&authorizationkey=rdec-key-123-45678-011121314"
urllib.request.urlretrieve(res, "./data/example.zip")
f = zipfile.ZipFile('./data/example.zip')
f.extractall('./data')

# %%
# 1. 請問高雄市有多少地區有溫度資料？

import xmltodict

# 存取檔案
count = 0
with open('./data/64_72hr_CH.xml','r',encoding='utf-8') as fd:
    doc = dict(xmltodict.parse(fd.read()))
    location = doc['cwbopendata']['dataset']['locations']['location']
    for locationName in location:
        count=count+1
        #print (locationName['locationName'])
print('總共有' + str(count) + '區')
# Out:
# 總共有38區

# %%
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
import xmltodict

# 存取檔案
with open('./data/64_72hr_CH.xml','r',encoding='utf-8') as fd:
    doc = dict(xmltodict.parse(fd.read()))

    locations = doc['cwbopendata']['dataset']['locations']['location']
    
    for location in locations:
        print (location['locationName'] )
        for weatherElement in location['weatherElement']:
            for time in weatherElement['time']:
                print ('第1個時間點 : '+time['dataTime'])
                print ('溫度 : '+time['elementValue']['value']+time['elementValue']['measures'])
                break
            break
        print('')
# Out:
# 鹽埕區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 26攝氏度
#
# 鼓山區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 26攝氏度
#
# 左營區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 26攝氏度
#
# 楠梓區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 27攝氏度
#
# 三民區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 26攝氏度
#
# 新興區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 26攝氏度
#
# 前金區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 26攝氏度
#
# 苓雅區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 26攝氏度
#
# 前鎮區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 26攝氏度
#
# 旗津區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 25攝氏度
#
# 小港區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 26攝氏度
#
# 鳳山區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 27攝氏度
#
# 林園區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 27攝氏度
#
# 大寮區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 27攝氏度
#
# 大樹區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 28攝氏度
#
# 大社區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 27攝氏度
#
# 仁武區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 27攝氏度
#
# 鳥松區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 27攝氏度
#
# 岡山區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 26攝氏度
#
# 橋頭區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 27攝氏度
#
# 燕巢區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 26攝氏度
#
# 田寮區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 25攝氏度
#
# 阿蓮區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 26攝氏度
#
# 路竹區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 26攝氏度
#
# 湖內區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 25攝氏度
#
# 茄萣區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 24攝氏度
#
# 永安區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 24攝氏度
#
# 彌陀區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 25攝氏度
#
# 梓官區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 25攝氏度
#
# 旗山區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 26攝氏度
#
# 美濃區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 27攝氏度
#
# 六龜區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 24攝氏度
#
# 甲仙區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 24攝氏度
#
# 杉林區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 26攝氏度
#
# 內門區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 26攝氏度
#
# 茂林區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 24攝氏度
#
# 桃源區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 21攝氏度
#
# 那瑪夏區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 19攝氏度

# %%
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度
import xmltodict

# 存取檔案
with open('./data/64_72hr_CH.xml','r',encoding='utf-8') as fd:
    doc = dict(xmltodict.parse(fd.read()))

    locations = doc['cwbopendata']['dataset']['locations']['location']
    
    count =0
    for location in locations:
        print (location['locationName'] )
        for weatherElement in location['weatherElement']:
            for time in weatherElement['time']:
                count=count+1
                print ('第'+ str(count) +'個時間點 : '+time['dataTime'])
                print ('溫度 : '+time['elementValue']['value']+time['elementValue']['measures'])
                print('')
            break
        break
# Out:
# 鹽埕區
# 第1個時間點 : 2020-02-26T18:00:00+08:00
# 溫度 : 26攝氏度
#
# 第2個時間點 : 2020-02-26T21:00:00+08:00
# 溫度 : 24攝氏度
#
# 第3個時間點 : 2020-02-27T00:00:00+08:00
# 溫度 : 22攝氏度
#
# 第4個時間點 : 2020-02-27T03:00:00+08:00
# 溫度 : 21攝氏度
#
# 第5個時間點 : 2020-02-27T06:00:00+08:00
# 溫度 : 21攝氏度
#
# 第6個時間點 : 2020-02-27T09:00:00+08:00
# 溫度 : 22攝氏度
#
# 第7個時間點 : 2020-02-27T12:00:00+08:00
# 溫度 : 26攝氏度
#
# 第8個時間點 : 2020-02-27T15:00:00+08:00
# 溫度 : 26攝氏度
#
# 第9個時間點 : 2020-02-27T18:00:00+08:00
# 溫度 : 25攝氏度
#
# 第10個時間點 : 2020-02-27T21:00:00+08:00
# 溫度 : 23攝氏度
#
# 第11個時間點 : 2020-02-28T00:00:00+08:00
# 溫度 : 22攝氏度
#
# 第12個時間點 : 2020-02-28T03:00:00+08:00
# 溫度 : 21攝氏度
#
# 第13個時間點 : 2020-02-28T06:00:00+08:00
# 溫度 : 21攝氏度
#
# 第14個時間點 : 2020-02-28T09:00:00+08:00
# 溫度 : 22攝氏度
#
# 第15個時間點 : 2020-02-28T12:00:00+08:00
# 溫度 : 26攝氏度
#
# 第16個時間點 : 2020-02-28T15:00:00+08:00
# 溫度 : 26攝氏度
#
# 第17個時間點 : 2020-02-28T18:00:00+08:00
# 溫度 : 25攝氏度
#
# 第18個時間點 : 2020-02-28T21:00:00+08:00
# 溫度 : 24攝氏度
#
# 第19個時間點 : 2020-02-29T00:00:00+08:00
# 溫度 : 23攝氏度
#
# 第20個時間點 : 2020-02-29T03:00:00+08:00
# 溫度 : 22攝氏度
#
# 第21個時間點 : 2020-02-29T06:00:00+08:00
# 溫度 : 22攝氏度
#
# 第22個時間點 : 2020-02-29T09:00:00+08:00
# 溫度 : 24攝氏度
#
# 第23個時間點 : 2020-02-29T12:00:00+08:00
# 溫度 : 28攝氏度
#
# 第24個時間點 : 2020-02-29T15:00:00+08:00
# 溫度 : 29攝氏度
